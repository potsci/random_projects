# %%
import os
import math
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize, signal
from pathlib import *

from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
# refpath=Path("I:\XRD\Thetascan")
# file = Path(askopenfilename(initialdir=refpath, title='´Select the folder, with images you want to normalise and select first image'))

# %%
file=Path("C:\\Users\lukas\sciebo\IMM\XRD_NRC\\analyse")

# %%
xys=list(file.glob('**\*.xy'))

# %%
xys
# Out:
# [WindowsPath('C:/Users/lukas/sciebo/IMM/XRD_NRC/analyse/Nb-42Ni/Nb-42Ni_background subtracted001_exported_cut.xy'),
#  WindowsPath('C:/Users/lukas/sciebo/IMM/XRD_NRC/analyse/Nb-49Ni/Nb-49ni_background subtracted.xy')]

# %%
datas=[]
for xy in file.glob('**\*.xy'):
    data=[]
    data=pd.read_csv(xy,sep=' ',skiprows=1,names=['2theta','intensity'])
    # if xy.stem[-1]=='4':
    #     data=data[data['2theta']>99]
    data['fname']=xy.parent.stem
    datas.append(data)
df=pd.concat(datas)

# %%
if xy.stem[-1]=='4':
    data=data[data['2theta']>99]

# %%
datas
# Out:
# [      2theta  intensity    fname
#  0      30.00     -0.033  Nb-42Ni
#  1      30.02     -0.036  Nb-42Ni
#  2      30.04     -0.030  Nb-42Ni
#  3      30.06     -0.055  Nb-42Ni
#  4      30.08     -0.030  Nb-42Ni
#  ...      ...        ...      ...
#  5010  130.20      0.122  Nb-42Ni
#  5011  130.22     -0.019  Nb-42Ni
#  5012  130.24      0.053  Nb-42Ni
#  5013  130.26     -0.039  Nb-42Ni
#  5014  130.28      0.000  Nb-42Ni
#
#  [5015 rows x 3 columns],
#        2theta  intensity    fname
#  0      30.00     -0.032  Nb-49Ni
#  1      30.02     -0.032  Nb-49Ni
#  2      30.04     -0.027  Nb-49Ni
#  3      30.06     -0.033  Nb-49Ni
#  4      30.08     -0.026  Nb-49Ni
#  ...      ...        ...      ...
#  4972  129.44      0.102  Nb-49Ni
#  4973  129.46     -0.096  Nb-49Ni
#  4974  129.48     -0.052  Nb-49Ni
#  4975  129.50      0.013  Nb-49Ni
#  4976  129.52      0.000  Nb-49Ni
#
#  [4977 rows x 3 columns]]

# %%
import matplotlib.cm

# %%
import matplotlib as mpl

# %%
# rgb(np.linspace(0,1,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 rgb(np.linspace(0,1,4))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
fig,ax=plt.subplots(figsize=(30,10))
import seaborn as sns
# color=['gray','red','blue']
rgb = mpl.cm.get_cmap('viridis',4)#[np.newaxis, :, :3]
rgb=rgb(np.linspace(0,1,4))
# colors=mp
i=0
for key in df['fname'].unique():
    print(key)
    data=df[df['fname']==key]
    # ax.scatter(data['2theta'],data['intensity']+i*10,s=0.5,color=rgb[i],label=key)
    if i==1:
        ax.plot(data['2theta'],data['intensity']+i*10,color=rgb[i],label=key)
    else:
        ax.plot(data['2theta']+0.9,data['intensity']+i*10,color=rgb[i],label=key)

    i=i+1
ax.legend()
ax.set_xlim(35,110)
plt.subplots
# Out:
# Nb-42Ni
# Nb-49Ni
# C:\Users\lukas\AppData\Local\Temp\ipykernel_11608\2007766666.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   rgb = mpl.cm.get_cmap('viridis',4)#[np.newaxis, :, :3]
# <function matplotlib.pyplot.subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True, width_ratios=None, height_ratios=None, subplot_kw=None, gridspec_kw=None, **fig_kw)>

# %%
plt.style.use('seaborn-talk')
fig,ax=plt.subplots()
import seaborn as sns
# color=['gray','red','blue']
rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# np.append(rgb,[[0,0,0,1]],axis=0)
rgb=rgb(np.linspace(0,0.85,4))
rgb =np.append(rgb,[[0,0,0,1]],axis=0)
# colors=mp
i=0
for key in df['fname'].unique():
    print(key)
    data=df[df['fname']==key]
    ax.scatter(data['2theta'],data['intensity']+i*500,s=0.5,color=rgb[i],label=key)
    i=i+1
ax.legend(markerscale=10)
ax.set_xlim(35,100)
plt.subplots
ax.set_xlabel('2 $/theta$ °')
axins = inset_axes(ax, width=2,loc='upper right' ,height=1.5,bbox_to_anchor=(500,450))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins.set_xlim(38,48)
axins.set_ylim(800,2500)
axins.set_yticks([])
axins.set_xlabel('2 theta')    
axins.xaxis.set_label_position('top') 
axins.tick_params(axis='x', which='major', pad=1)
axins2 = inset_axes(ax, width=2,loc='upper right' ,height=1.5,bbox_to_anchor=(700,450))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins2.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins2.set_yticks([])
axins2.set_xlim(48,58)
axins2.set_ylim(450,1750)
axins2.tick_params(axis='x', which='major', pad=1)

axins3 = inset_axes(ax, width=2,loc='upper right' ,height=1.5,bbox_to_anchor=(500,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins3.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins3.set_yticks([])
axins3.set_xlim(58,68)
axins3.set_ylim(300,1400)
axins3.xaxis.tick_top()

axins4 = inset_axes(ax, width=2,loc='upper right' ,height=1.5,bbox_to_anchor=(700,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins4.scatter(data['2theta'],data['intensity']+i*120,s=0.5,color=rgb[i],label=key)
    i=i+1
axins4.set_yticks([])
axins4.set_xlim(68,78)
axins4.set_ylim(250,900)
axins4.xaxis.tick_top()
# Out:
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\3570870917.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\3570870917.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# 50_45_3mm_dic
# 50_45_4mm_dic
# 50_45_5mm_dic
# 50_45_head_dic
# C02_ascast

# %%
# C36 = xu.materials.Crystal('C36_Amerioun',xu.materials.SGLattice(194, 5.853,18.897,
#                                                                  atoms=[Mg,Al],#,Mg,Al,Al,Al,Ca,Ca],
#                                                                  pos=[('4f',(0.1291)),('6h')],#,('6g',(0,0.5,0.5)),('4f',(0.33333,0.66667,0.1291)),('6h',(0.1631,0.3262,0.25)),('6g',(0,0.5,0.5)),('4e',(0,0,0.0939)),('4f',(0.3333,0.66667,0.8428))],
#                                                                  occ=[0.72,0.28]#,0.81,0.19,0.5,0.5,1,1]
# ))

# %%
import numpy as np

import xrayutilities as xu
dif=xu.simpack.PowderDiffraction(Mg,en=energy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 import numpy as np
#       3 import xrayutilities as xu
# ----> 4 dif=xu.simpack.PowderDiffraction(Mg,en=energy)
#
# NameError: name 'Mg' is not defined

# %%
import numpy as np

import xrayutilities as xu


energy = 6403.84 ##https://xdb.lbl.gov/Section1/Table_1-2.pdf

# creating powder experiment

xup = xu.PowderExperiment(en=energy)

theta = np.arange(35,126, 0.01)
Mg=[]
Mg = xu.materials.elements.Mg

Al = xu.materials.elements.Al
Ca= xu.materials.elements.Ca
# c36_lattice=xu.materials.SGLattice(194, 5.853,18.897,)
# c36_wyck=c36_lattice.WyckofBase
wb=xu.materials.spacegrouplattice.WyckoffBase
C36 = xu.materials.Crystal('C36_Amerioun',xu.materials.SGLattice(194, 5.85,19.05,
                                                                 atoms=[Mg,Mg,Mg,Al,Al,Al,Ca,Ca],
                                                                 pos=[('4f',0.1291),(0.1631,0.3262,0.25),(0,0.5,0.5),('4f',0.1291),(0.1631,0.3262,0.25),(0,0.5,0.5),(0,0,0.0939),('4f',0.8428)],
                                                                 occ=[0.28,0.19,0.5,0.72,0.81,0.5,1,1]
                                                                 ))
C14 = xu.materials.Crystal('C14_Amerioun',xu.materials.SGLattice(194,6.251,10.141,
                                                                 atoms=[Mg,Ca,Mg],
                                                                 pos=[(0.1697,0.3394,0.25),(0.333333333333333,0.666666666666667,0.5629),(0,0,0)],
                                                                 occ=[1,1,1]
                                                                 ))
mat = xu.materials.Crystal('Mg',xu.materials.SGLattice(194, 3.205922,5.1986,atoms=['Mg'],pos=[('2c')]))

q = xup.Ang2Q(theta)
dif_mg=xu.simpack.PowderDiffraction(mat,en=energy)
dif_c36=xu.simpack.PowderDiffraction(C36,en=energy)
dif_c14=xu.simpack.PowderDiffraction(C14,en=energy)
# dif.profile_data()
# dif.energy=energy
# dif.init_powder_lines(35)
# print(dif)

# dif.energy
miller_mg=[]
angles_mg=[]
intensities_mg=[]
for key in dif_mg.data.keys():
    miller_mg.append(key)
    angles_mg.append(dif_mg.data[key]['ang']*2)
    intensities_mg.append(dif_mg.data[key]['r'])
    # dif.energy
miller_c36=[]
angles_c36=[]

intensities_c36=[]
for key in dif_c36.data.keys():
    miller_c36.append(key)
    angles_c36.append(dif_c36.data[key]['ang']*2)
    intensities_c36.append(dif_c36.data[key]['r'])

angles_c14=[]
miller_c14=[]
intensities_c14=[]
for key in dif_c14.data.keys():
    miller_c14.append(key)
    angles_c14.append(dif_c14.data[key]['ang']*2)
    intensities_c14.append(dif_c14.data[key]['r'])
# Out:
# XU.materials.SGLattice: position (0.1631, 0.3262, 0.25) identified as ('6h', [0.1631])
# XU.materials.SGLattice: position (0, 0.5, 0.5) identified as 6g
# XU.materials.SGLattice: position (0.1631, 0.3262, 0.25) identified as ('6h', [0.1631])
# XU.materials.SGLattice: position (0, 0.5, 0.5) identified as 6g
# XU.materials.SGLattice: position (0, 0, 0.0939) identified as ('4e', [0.4061])
# XU.materials.SGLattice: position (0.1697, 0.3394, 0.25) identified as ('6h', [0.1697])
# XU.materials.SGLattice: position (0.333333333333333, 0.666666666666667, 0.5629) identified as ('4f', [0.5629])
# XU.materials.SGLattice: position (0, 0, 0) identified as 2a

# %%
max_c36=max(intensities_c36)

# %%
plt.style.use('seaborn-talk')
fig,ax=plt.subplots()
import seaborn as sns
# color=['gray','red','blue']
rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# np.append(rgb,[[0,0,0,1]],axis=0)
rgb=rgb(np.linspace(0,0.85,4))
rgb =np.append(rgb,[[0,0,0,1]],axis=0)
# colors=mp
i=0
for key in df['fname'].unique():
    print(key)
    data=df[df['fname']==key]
    ax.scatter(data['2theta'],data['intensity']+i*500,s=0.5,color=rgb[i],label=key)
    i=i+1
ax.legend()
ax.set_xlim(35,110)
plt.subplots
ax.set_xlabel('2 $/theta$ °')
axins = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(530,450))

for ang in angles_mg:
    ax.axvline(x=ang,ymin=0,ymax=5000)
k=0
for ang in angles_c36:
    if intensities_c36[k]>0.1*max_c36:
        ax.axvline(x=ang,ymin=0,ymax=5000,color='black')
    k=k+1
i=0

for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins.set_xlim(38,48)
axins.set_ylim(800,2500)
axins.set_yticks([])
axins.set_xlabel('2 theta')    
axins.xaxis.set_label_position('top') 
axins.tick_params(axis='x', which='major', pad=1)
axins2 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(760,450))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins2.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins2.set_yticks([])
axins2.set_xlim(48,58)
axins2.set_ylim(450,1750)
axins2.tick_params(axis='x', which='major', pad=1)

axins3 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(530,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins3.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins3.set_yticks([])
axins3.set_xlim(58,68)
axins3.set_ylim(300,1400)
axins3.xaxis.tick_top()

axins4 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(760,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins4.scatter(data['2theta'],data['intensity']+i*120,s=0.5,color=rgb[i],label=key)
    i=i+1
axins4.set_yticks([])
axins4.set_xlim(68,78)

axins4.set_ylim(250,900)
axins4.xaxis.tick_top()
# Out:
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\2758087241.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\2758087241.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# 50_45_3mm_dic
# 50_45_4mm_dic
# 50_45_5mm_dic
# 50_45_head_dic
# C02_ascast

# %%
plt.style.use('seaborn-talk')
fig,ax=plt.subplots()
import seaborn as sns
# color=['gray','red','blue']
rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# np.append(rgb,[[0,0,0,1]],axis=0)
rgb=rgb(np.linspace(0,0.85,4))
rgb =np.append(rgb,[[0,0,0,1]],axis=0)
# colors=mp
i=0
for key in df['fname'].unique():
    print(key)
    data=df[df['fname']==key]
    ax.scatter(data['2theta'],data['intensity']+i*500,s=0.5,color=rgb[i],label=key)
    i=i+1
ax.legend()
ax.set_xlim(35,110)
plt.subplots
ax.set_xlabel('2 $/theta$ °')
axins = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(530,450))

for ang in angles_mg:
    ax.axvline(x=ang,ymin=0,ymax=5000)
k=0
for ang in angles_c36:
    # if intensities_c36[k]>0.1*max_c36:
    ax.plot([ang,ang],[0,intensities_c36[k]*1000],color='black')
    k=k+1
# i=0
k=0
for ang in angles_c14:
    # if intensities_c36[k]>0.1*max_c36:
    ax.plot([ang,ang],[0,intensities_c14[k]*1000],'b--')
    k=k+1
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    k=0
    for ang in angles_c36:
    # if intensities_c36[k]>0.1*max_c36:
        axins.plot([ang,ang],[0,intensities_c36[k]*1000+200],color='black')
    k=k+1
    i=i+1
axins.set_xlim(38,48)
axins.set_ylim(800,2500)
axins.set_yticks([])
axins.set_xlabel('2 theta')    
axins.xaxis.set_label_position('top') 
axins.tick_params(axis='x', which='major', pad=1)
axins2 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(760,450))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins2.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins2.set_yticks([])
axins2.set_xlim(48,58)
axins2.set_ylim(450,1750)
axins2.tick_params(axis='x', which='major', pad=1)

axins3 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(530,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins3.scatter(data['2theta'],data['intensity']+i*200,s=0.5,color=rgb[i],label=key)
    i=i+1
axins3.set_yticks([])
axins3.set_xlim(58,68)
axins3.set_ylim(300,1400)
axins3.xaxis.tick_top()

axins4 = inset_axes(ax, width=2.3,loc='upper right' ,height=1.5,bbox_to_anchor=(760,600))
i=0
for key in df['fname'].unique():
    # print(key)
    data=df[df['fname']==key]
    axins4.scatter(data['2theta'],data['intensity']+i*120,s=0.5,color=rgb[i],label=key)
    i=i+1
axins4.set_yticks([])
axins4.set_xlim(68,78)

axins4.set_ylim(250,900)
axins4.xaxis.tick_top()
# Out:
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\3971404723.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')
# C:\Users\berners\AppData\Local\Temp\ipykernel_9280\3971404723.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   rgb = mpl.cm.get_cmap('viridis')#[np.newaxis, :, :3]
# 50_45_3mm_dic
# 50_45_4mm_dic
# 50_45_5mm_dic
# 50_45_head_dic
# C02_ascast

# %%
cif_c36=xu.materials.cif.CIFFile('I:\CIF\C36.cif')

# %%
with open('I:\CIF\C36.cif') as f:
    c36_data=xu.materials.cif.CIFDataset(f,'c36_mg',digits=4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# i:\python\Notebooks\random_projects_lukas\xrd\peak_finding_xrd.ipynb Zelle 20 line 2
#       <a href='vscode-notebook-cell:/i%3A/python/Notebooks/random_projects_lukas/xrd/peak_finding_xrd.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> with open('I:\CIF\C36.cif') as f:
# ----> <a href='vscode-notebook-cell:/i%3A/python/Notebooks/random_projects_lukas/xrd/peak_finding_xrd.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>     c36_data=xu.materials.cif.CIFDataset(f,'c36_mg',digits=4)
#
# File c:\Users\berners\AppData\Local\Programs\Python\Python39\lib\site-packages\xrayutilities\materials\cif.py:199, in CIFDataset.__init__(self, fid, name, digits)
#     197 if config.VERBOSITY >= config.INFO_ALL:
#     198     print('XU.materials: parsing cif dataset %s' % self.name)
# --> 199 self.Parse(fid)
#     200 self.SymStruct()
#
# File c:\Users\berners\AppData\Local\Programs\Python\Python39\lib\site-packages\xrayutilities\materials\cif.py:283, in CIFDataset.Parse(self, fid)
#     281 for line in fid.readlines():
#     282     linelen = len(line)
# --> 283     line = line.decode('ascii', 'ignore')
#     284     if config.VERBOSITY >= config.DEBUG:
#     285         print(line)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
pd.read_csv('I:\CIF\Mg\Mg.txt',sep='  ')
# Out:
# C:\Users\berners\AppData\Local\Temp\ipykernel_15636\2646380299.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv('I:\CIF\Mg\Mg.txt',sep='  ')
#      h  Unnamed: 1    k  Unnamed: 3        l  Unnamed: 5  Unnamed: 6
# 0    0         NaN  0.0    -1.00000  5.20990         NaN         0.0  \
# 1    0         NaN  0.0         NaN  1.00000    5.209900         NaN
# 2    0         NaN  0.0    -1.00000  5.20990         NaN         0.0
# 3    0         NaN  0.0         NaN  1.00000    5.209900         NaN
# 4    1         NaN  0.0         NaN  0.00000    2.779249         NaN
# ..  ..         ...  ...         ...      ...         ...         ...
# 311  2        -1.0 -3.0     1.17854      NaN    0.000000         NaN
# 312 -2         NaN  1.0         NaN  3.00000    1.178540         NaN
# 313 -1         NaN  2.0    -3.00000  1.17854         NaN         0.0
# 314  2        -1.0 -3.0     1.17854      NaN    0.000000         NaN
# 315  1        -2.0  NaN     3.00000  1.17854         NaN         0.0
#
#          d(Å)  Unnamed: 8  Unnamed: 9  ...  Unnamed: 20  Unnamed: 21   2θ
# 0         NaN         0.0         NaN  ...          NaN          1.0  NaN  \
# 1    0.000000         NaN    0.000000  ...          1.0          NaN  1.0
# 2         NaN         0.0         NaN  ...          NaN          2.0  NaN
# 3    0.000000         NaN    0.000000  ...          1.0          NaN  2.0
# 4   -9.256868         NaN   -0.286576  ...          1.0          NaN  NaN
# ..        ...         ...         ...  ...          ...          ...  ...
# 311  0.000000         NaN         NaN  ...          2.0          NaN  3.0
# 312  0.000000         NaN    0.000000  ...          1.0          NaN  1.0
# 313       NaN         0.0         NaN  ...          NaN          1.0  NaN
# 314  0.000000         NaN         NaN  ...          1.0          NaN  3.0
# 315       NaN         0.0         NaN  ...          NaN          1.0  NaN
#
#      Unnamed: 23  Unnamed: 24  Unnamed: 25  Unnamed: 26   I  Unnamed: 28
# 0            3.0          NaN          NaN          NaN NaN          NaN  \
# 1            NaN          3.0          NaN          NaN NaN          NaN
# 2            3.0          NaN          NaN          NaN NaN          NaN
# 3            NaN          3.0          NaN          NaN NaN          NaN
# 4            NaN          NaN          NaN          NaN NaN          NaN
# ..           ...          ...          ...          ...  ..          ...
# 311          NaN          NaN          NaN          NaN NaN          NaN
# 312          NaN          3.0          NaN          NaN NaN          NaN
# 313          3.0          NaN          NaN          NaN NaN          NaN
# 314          NaN          NaN          NaN          NaN NaN          NaN
# 315          3.0          NaN          NaN          NaN NaN          NaN
#
#      M ID(λ) Phase
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 311            NaN
# 312            NaN
# 313            NaN
# 314            NaN
# 315            NaN
#
# [316 rows x 30 columns]

# %%
angles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# i:\python\Notebooks\random_projects_lukas\peak_finding_xrd.ipynb Zelle 20 line 1
# ----> <a href='vscode-notebook-cell:/i%3A/python/Notebooks/random_projects_lukas/peak_finding_xrd.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> angles
#
# NameError: name 'angles' is not defined
