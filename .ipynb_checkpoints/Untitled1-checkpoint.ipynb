# %%
from pymontecarlo_casino2.program import Casino2Program
from pymontecarlo.options.material import Material
from pymontecarlo.options.sample import SubstrateSample
from pymontecarlo.options.beam import PencilBeam

# %%
import math
incident_angle=70
in_x=math.cos(incident_angle*2*math.pi/360)
in_z=math.sin(incident_angle*2*math.pi/360)

# %%
program=Casino2Program(5000)

# %%
beam = PencilBeam(15e3,(in_x,0,in_z))

# %%
pip install pymontecarlo-casino2
# Out:
# Requirement already satisfied: pymontecarlo-casino2 in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: pycasinotools in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo-casino2) (0.2.2)
# Requirement already satisfied: pymontecarlo in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo-casino2) (1.1.0)
# Requirement already satisfied: pyxray in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo-casino2) (1.8.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from pycasinotools->pymontecarlo-casino2) (1.20.3)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from pycasinotools->pymontecarlo-casino2) (8.4.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (4.62.3)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (1.3.4)
# Requirement already satisfied: pint in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (0.18)
# Requirement already satisfied: docutils in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (0.17.1)
# Requirement already satisfied: uncertainties in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (3.1.7)
# Requirement already satisfied: h5py in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (3.2.1)
# Requirement already satisfied: more-itertools in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (8.10.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (3.4.3)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from pymontecarlo->pymontecarlo-casino2) (3.0.4)
# Requirement already satisfied: psutil in c:\users\berners\appdata\roaming\python\python39\site-packages (from pymontecarlo->pymontecarlo-casino2) (5.9.4)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pymontecarlo->pymontecarlo-casino2) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->pymontecarlo->pymontecarlo-casino2) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\berners\appdata\roaming\python\python39\site-packages (from matplotlib->pymontecarlo->pymontecarlo-casino2) (2.8.2)
# Requirement already satisfied: six in c:\users\berners\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib->pymontecarlo->pymontecarlo-casino2) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->pymontecarlo->pymontecarlo-casino2) (2021.3)
# Requirement already satisfied: packaging in c:\users\berners\appdata\roaming\python\python39\site-packages (from pint->pymontecarlo->pymontecarlo-casino2) (23.0)
# Requirement already satisfied: tabulate in c:\programdata\anaconda3\lib\site-packages (from pyxray->pymontecarlo-casino2) (0.9.0)
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (from pyxray->pymontecarlo-casino2) (1.4.22)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy->pyxray->pymontecarlo-casino2) (1.1.1)
# Requirement already satisfied: colorama in c:\users\berners\appdata\roaming\python\python39\site-packages (from tqdm->pymontecarlo->pymontecarlo-casino2) (0.4.6)
# Requirement already satisfied: future in c:\programdata\anaconda3\lib\site-packages (from uncertainties->pymontecarlo->pymontecarlo-casino2) (0.18.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)

# %%
import matplotlib.pyplot as plt
from pymontecarlo.figures.sample import SampleFigure, Perspective

fig, axes = plt.subplots(1, 3, figsize=(10, 3))

samplefig = SampleFigure(substrate, beams=[beam])

for ax, perspective in zip(axes, Perspective):
    samplefig.perspective = perspective
    samplefig.draw(ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 10
#       8 for ax, perspective in zip(axes, Perspective):
#       9     samplefig.perspective = perspective
# ---> 10     samplefig.draw(ax)
#      12 plt.show()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pymontecarlo\figures\sample.py:137, in SampleFigure.draw(self, ax)
#     134     self._draw_sample(ax, self.sample, self.perspective, view_size)
#     136 for beam in self.beams:
# --> 137     self._draw_beam(ax, beam, self.perspective, view_size)
#     139 for trajectory in self.trajectories:
#     140     self._draw_trajectory(ax, trajectory, self.perspective, view_size)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pymontecarlo\figures\sample.py:346, in SampleFigure._draw_beam(self, ax, beam, perspective, view_size)
#     342     return
#     344 method = self.beam_draw_methods[beam_class]
# --> 346 patches = method(beam, perspective, view_size)
#     347 col = PatchCollection(patches, match_original=True)
#     349 # TODO rotate
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pymontecarlo\figures\sample.py:362, in SampleFigure._compose_beam_pencil(self, beam, perspective, view_size)
#     360 x0_m = beam.x0_m
#     361 y0_m = beam.y0_m
# --> 362 color = beam.particle.color
#     364 if perspective is Perspective.XY:
#     365     return [
#     366         RegularPolygon(
#     367             (x0_m, y0_m), numVertices=3, radius=view_size / 100, color=color
#     368         )
#     369     ]
#
# AttributeError: 'tuple' object has no attribute 'color'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 casinotools.fileformat.casino2.GraphData()
#
# TypeError: 'module' object is not callable

# %%
import casinotools
import casinotools.fileformat.casino2 as cas2
from casinotools.fileformat import FileReaderWriterTools
import matplotlib.pyplot as plt

# %%
FileReaderWriterTools.FileReaderWriterTools.
# Out:
#   Cell In[7], line 1
#     FileReaderWriterTools.FileReaderWriterTools.
#                                                 ^
# SyntaxError: invalid syntax

# %%
mg_sim=cas2.File.File()

# %%
mg_sim.readFromFilepath(filepath="I:/Mc_sim/Mg_5kv_5000.cas")

# %%
mg_sim_5kv_results=mg_sim.getResultsSimulation(0)

# %%
mg_sim_5kv_trajectories=mg_sim_5kv_results.getTrajectoriesData()

# %%
traj=mg_sim_5kv_trajectories.getTrajectories()

# %%
scatterings_traj_1=traj[0].getScatteringEvents()

# %%
from operator import attrgetter
xgetter=attrgetter('X')
print(xgetter(scatterings_traj_1))

# %%
cords= [(ev.X,ev.Y) for ev in scatterings_traj_1]
# y_val= [ev.Y for e]

# %%
traj

# %%
for j in range(0,10):
    scatterings_traj_1 = traj[j].getScatteringEvents()
#     print(j)
    for i in range(0,len(scatterings_traj_1)):
        traj=
        plt.scatter(scatterings_traj_1[i].Y,scatterings_traj_1[i].X)

# %%
scatterings_traj_1.X
scatterings_traj_1.Y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 scatterings_traj_1.X
#       2 scatterings_traj_1.Y
#
# AttributeError: 'list' object has no attribute 'X'

# %%
pip install casinotools
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement casinotools (from versions: none)
# ERROR: No matching distribution found for casinotools
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
