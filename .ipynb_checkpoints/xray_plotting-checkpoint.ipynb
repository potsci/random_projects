# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from tkinter.filedialog import askopenfilename
from pathlib import *
import os

# %%
refpath=Path("I:\XRD\Thetascan")

# %%
file = Path(askopenfilename(initialdir=refpath, title='´Select the folder, with images you want to normalise and select first image'))

# %%
paths=list(file.parent.glob('**/*.xy'))
paths
# Out:
# [WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C15min_2_exported_1.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C15min_2_exported_2.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C15min_2_exported_3.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C15min_2_exported_4.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C30min_exported_1.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C30min_exported_2.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C30min_exported_3.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C30min_exported_4.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C4H_exported_1.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C4H_exported_2.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C4H_exported_3.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500C4H_exported_4.xy'),
#  WindowsPath('I:/XRD/Thetascan/C02/HT/all/C2ht500Cac_exported_1.xy'),
# ...

# %%
m_vals=[58.5,]
for key in paths:
    tmp=np.genfromtxt(key)
    if key.split('_exported_')[2]=1
    elif key.split('_exported_')[2]=1
    elif key.split('_exported_')[2]=1
    elif key.split('_exported_')[2]=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10848/1344877333.py in <module>
#       1 for key in paths:
# ----> 2     tmp=np.genfromtxt(key)
#       3 paths[0].stem.split('_exported')
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2120             # Raise an exception ?
#    2121             if invalid_raise:
# -> 2122                 raise ValueError(errmsg)
#    2123             # Issue a warning ?
#    2124             else:
#
# ValueError: Some errors were detected !
#     Line #2 (got 2 columns instead of 15)
# ...

# %%
    tmp=np.genfromtxt(key,skip_header=1)
    tmp
# Out:
# array([[  35.   , 2084.296],
#        [  35.01 , 2079.937],
#        [  35.02 , 2080.355],
#        ...,
#        [  65.98 ,  426.221],
#        [  65.99 ,  422.356],
#        [  66.   ,  416.849]])
