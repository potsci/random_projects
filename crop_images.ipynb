# %%
from PIL import Image 
Image.MAX_IMAGE_PIXELS = None
from pathlib import *

# %%
# path=Path('/rwthfs/rz/cluster/work/mz071159/quasi-in-situ/50_45_leo/head/')
path=Path('J:\\Users\Berners_Lukas\LEO\yolov5\\50_45\man_slip\head\\eps5_recheck\panos')

print(list(path.glob('**/*')))
#%%
height=4000
width=4000   
i=0
j=0
imsize=[]
croppath1=path.joinpath('crop')
croppath1.mkdir(parents=True, exist_ok=True)
# Out:
# [WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area2'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area3'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area4'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area5'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area6'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/crop'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/50_45_head_area1_pano_stitch.png'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/im_sizes.txt'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c000_r000.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c000_r001.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c000_r002.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c001_r000.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c001_r001.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c001_r002.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c002_r000.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c002_r001.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c002_r002.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c003_r000.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c003_r001.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/50_45_head_area1_pano_stitch_c003_r002.jpg'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/area1'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area1/crop/Thumbs.db'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area2/50_45_head_area2_pano_stitch.png'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area3/50_45_head_area3_pano_stitch.png'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area4/50_45_head_area4_pano_stitch.png'), WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/area5/50_45_head_area5_pano_stitch.png')]

# %%
for imgpath in list(path.glob('**/*.png')):
    i=0
    j=0
    # imgpath.parents[2]
    croppath=croppath1.joinpath(imgpath.parent.stem)
    croppath.mkdir(parents=True, exist_ok=True)
    img = Image.open(str(imgpath))
    for c in range(0,img.size[0],width):
        j=0
        for r in range(0,img.size[1],height):
            print([c,r])
            if c+width<img.size[0]:
                c_bound=c+width
            else:
                c_bound=img.size[0]
            if r+height<img.size[1]:
                r_bound=r+height
            else:
                r_bound=img.size[1]
            
            img_crop=img.crop((c,r,c_bound,r_bound))
            print(img_crop.size)
            img_crop.save(f"{croppath1}/{imgpath.stem}_c{i:03d}_r{j:03d}.jpg")
            print(f"{croppath1}/{imgpath.stem}_c{i:03d}_r{j:03d}.jpg")
            imsize.append(img_crop.size)
            j=j+1
        i=i+1
        

with open(str(path) + '/im_sizes.txt', 'w') as f:
    for item in imsize:
        f.write(f"{item[0]}\t{item[1]}\n")
    f.write(f"{i}\t{j}")
# %%
list(path.glob('**/*.png'))
#%%
list(path.glob('*.jpg'))
# %%
item[0]
# %%
croppath=imgpath.parents[1].joinpath('crop')
#%%
croppath.mkdir(parents=True, exist_ok=True)
croppath.joinpath(imgpath.parent.stem)
# Out:
# [0, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c000_r000.jpg
# [0, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c000_r001.jpg
# [0, 8000]
# (4000, 23)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c000_r002.jpg
# [4000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c001_r000.jpg
# [4000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c001_r001.jpg
# [4000, 8000]
# (4000, 23)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c001_r002.jpg
# [8000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c002_r000.jpg
# [8000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c002_r001.jpg
# [8000, 8000]
# (4000, 23)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c002_r002.jpg
# [12000, 0]
# (1125, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c003_r000.jpg
# [12000, 4000]
# (1125, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c003_r001.jpg
# [12000, 8000]
# (1125, 23)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area1_pano_stitch_c003_r002.jpg
# [0, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c000_r000.jpg
# [0, 4000]
# (4000, 3723)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c000_r001.jpg
# [4000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c001_r000.jpg
# [4000, 4000]
# (4000, 3723)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c001_r001.jpg
# [8000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c002_r000.jpg
# [8000, 4000]
# (4000, 3723)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c002_r001.jpg
# [12000, 0]
# (1181, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c003_r000.jpg
# [12000, 4000]
# (1181, 3723)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area2_pano_stitch_c003_r001.jpg
# [0, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c000_r000.jpg
# [0, 4000]
# (4000, 3733)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c000_r001.jpg
# [4000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c001_r000.jpg
# [4000, 4000]
# (4000, 3733)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c001_r001.jpg
# [8000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c002_r000.jpg
# [8000, 4000]
# (4000, 3733)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c002_r001.jpg
# [12000, 0]
# (909, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c003_r000.jpg
# [12000, 4000]
# (909, 3733)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area3_pano_stitch_c003_r001.jpg
# [0, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c000_r000.jpg
# [0, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c000_r001.jpg
# [0, 8000]
# (4000, 970)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c000_r002.jpg
# [4000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c001_r000.jpg
# [4000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c001_r001.jpg
# [4000, 8000]
# (4000, 970)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c001_r002.jpg
# [8000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c002_r000.jpg
# [8000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c002_r001.jpg
# [8000, 8000]
# (4000, 970)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c002_r002.jpg
# [12000, 0]
# (1178, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c003_r000.jpg
# [12000, 4000]
# (1178, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c003_r001.jpg
# [12000, 8000]
# (1178, 970)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area4_pano_stitch_c003_r002.jpg
# [0, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c000_r000.jpg
# [0, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c000_r001.jpg
# [0, 8000]
# (4000, 1961)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c000_r002.jpg
# [4000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c001_r000.jpg
# [4000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c001_r001.jpg
# [4000, 8000]
# (4000, 1961)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c001_r002.jpg
# [8000, 0]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c002_r000.jpg
# [8000, 4000]
# (4000, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c002_r001.jpg
# [8000, 8000]
# (4000, 1961)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c002_r002.jpg
# [12000, 0]
# (639, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c003_r000.jpg
# [12000, 4000]
# (639, 4000)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c003_r001.jpg
# [12000, 8000]
# (639, 1961)
# J:\Users\Berners_Lukas\LEO\yolov5\50_45\man_slip\head\eps5_recheck\panos\crop/50_45_head_area5_pano_stitch_c003_r002.jpg
# WindowsPath('J:/Users/Berners_Lukas/LEO/yolov5/50_45/man_slip/head/eps5_recheck/panos/crop/area5')
