# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from pathlib import *

# %%
path=Path("J:\\Users\Berners_Lukas\Fib\quasi_in_situ\\50_45\\head_yolo\eps5_5kv\eds")
csv=path.joinpath('head_area2.csv')

# %%
df=pd.read_csv(csv,header=12)
df
# Out:
#                                               Element   Gew%  Atom %  Fehler%
# 0   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN  \
# 1                                                C  K  19.88   33.44    32.04
# 2                                                O  K   9.48   11.97    31.38
# 3                                                Mg K  31.86   26.48    11.93
# 4                                                Al K  34.98   26.20    13.56
# 5                                                Ca K   3.80    1.91    92.12
# 6   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN
# 7                                                C  K   0.62    1.27    18.35
# 8                                                O  K   0.07    0.10    64.37
# 9                                                Mg K  92.34   93.38     2.45
# 10                                               Al K   3.24    2.95     6.68
# ...

# %%
df['spot']=df['Element'].str.extract('((?<=EDS Spot )\d*)')

# %%
df['spot'].ffill(inplace=True)
df
# Out:
#                                               Element   Gew%  Atom %  Fehler%
# 0   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN  \
# 1                                                C  K  19.88   33.44    32.04
# 2                                                O  K   9.48   11.97    31.38
# 3                                                Mg K  31.86   26.48    11.93
# 4                                                Al K  34.98   26.20    13.56
# 5                                                Ca K   3.80    1.91    92.12
# 6   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN
# 7                                                C  K   0.62    1.27    18.35
# 8                                                O  K   0.07    0.10    64.37
# 9                                                Mg K  92.34   93.38     2.45
# 10                                               Al K   3.24    2.95     6.68
# ...

# %%
df
# Out:
#                                               Element   Gew%  Atom %  Fehler%
# 0   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN  \
# 1                                                C  K  19.88   33.44    32.04
# 2                                                O  K   9.48   11.97    31.38
# 3                                                Mg K  31.86   26.48    11.93
# 4                                                Al K  34.98   26.20    13.56
# 5                                                Ca K   3.80    1.91    92.12
# 6   SFB_Samples_cooling_rate | 50_45_head_yolo | A...    NaN     NaN      NaN
# 7                                                C  K   0.62    1.27    18.35
# 8                                                O  K   0.07    0.10    64.37
# 9                                                Mg K  92.34   93.38     2.45
# 10                                               Al K   3.24    2.95     6.68
# ...

# %%
Mg=np.array([1,7,8,9,10])
Mg=np.char.mod('%d',Mg)

df[~df['spot'].isin(Mg)].groupby('Element').mean()
# Out:
#                                                       Gew%  Atom %  Fehler%
# Element
# Al K                                                11.610  11.158    5.174  \
# C  K                                                 1.438   3.098   14.250
# Ca K                                                10.920   7.088    6.116
# Mg K                                                75.862  78.378    2.384
# O  K                                                 0.168   0.274   41.288
# SFB_Samples_cooling_rate | 50_45_head_yolo | Ar...     NaN     NaN      NaN
# SFB_Samples_cooling_rate | 50_45_head_yolo | Ar...     NaN     NaN      NaN
# SFB_Samples_cooling_rate | 50_45_head_yolo | Ar...     NaN     NaN      NaN
# SFB_Samples_cooling_rate | 50_45_head_yolo | Ar...     NaN     NaN      NaN
# SFB_Samples_cooling_rate | 50_45_head_yolo | Ar...     NaN     NaN      NaN
#
#                                                     Netto-Intensität
# Element
# ...

# %%
Mg=np.array([5,6,2,3,4,1])
np.char.mod('%d',Mg)
df[df['spot'].isin(Mg)].groupby('Element').mean()
# Out:
# Empty DataFrame
# Columns: [Gew%, Atom %, Fehler%, Netto-Intensität, K - Verhältnis, Z, A, F, spot]
# Index: []
